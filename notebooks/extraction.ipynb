# %%
import os
from landmarks import facial_landmarks

# %% [markdown]
# # fer_mediapipe folder

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test" # [train, val, test] folders

for folder in os.listdir(directory):
    folder_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test" + "\\" + folder 
    for classes in os.listdir(folder_directory):
        class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test" + "\\" + folder  + "\\" + classes
        os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test" + "\\" + folder + "\\"  + classes)
        for image in os.listdir(class_directory):
            if image.endswith(".jpg"):
                try:
                    facial_landmarks.get_facial_landmarks(image)
                except:
                    print("skipped")

# %% [markdown]
# # kdef_train_val_test folder

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test" # [train, val, test] folders

for folder in os.listdir(directory):
    folder_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test" + "\\" + folder 
    for classes in os.listdir(folder_directory):
        class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test" + "\\" + folder  + "\\" + classes
        os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test" + "\\" + folder + "\\"  + classes)
        for image in os.listdir(class_directory):
            if image.endswith(".jpg"):
                try:
                    facial_landmarks.get_facial_landmarks(image)
                except:
                    print("skipped")

# %% [markdown]
# # ckplus_train_val_test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test" # [train, val, test] folders

for folder in os.listdir(directory):
    folder_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test" + "\\" + folder 
    for classes in os.listdir(folder_directory):
        class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test" + "\\" + folder  + "\\" + classes
        os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test" + "\\" + folder + "\\"  + classes)
        for image in os.listdir(class_directory):
            if image.endswith(".jpg"):
                try:
                    facial_landmarks.get_facial_landmarks(image)
                except:
                    print("skipped")

# %% [markdown]
# # ffhq_train_val_test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ffhq_train_val_test\ffhq_train_val_test" # [train, val, test] folders

for folder in os.listdir(directory):
    folder_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ffhq_train_val_test\ffhq_train_val_test" + "\\" + folder 
    for classes in os.listdir(folder_directory):
        class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ffhq_train_val_test\ffhq_train_val_test" + "\\" + folder  + "\\" + classes
        os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ffhq_train_val_test\ffhq_train_val_test" + "\\" + folder + "\\"  + classes)
        for image in os.listdir(class_directory):
            if image.endswith(".jpg"):
                try:
                    facial_landmarks.get_facial_landmarks(image)
                except:
                    print("skipped")

# %% [markdown]
# # affectnet_train_val_test

# %%
C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test

# %%
# %pwd
# Out:
# 'C:\\Users\\kings\\OneDrive - MMU\\MSC DATA SCIENCE\\MSC Project\\datasets\\affectnet_train_val_test\\affectnet_train_val_test\\val\\sad'

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test" # [train, val, test] folders

for folder in os.listdir(directory)[1:]:
    folder_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test" + "\\" + folder 
    for classes in os.listdir(folder_directory):
        class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test" + "\\" + folder  + "\\" + classes
        os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test" + "\\" + folder + "\\"  + classes)
        for image in os.listdir(class_directory):
            if image.endswith(".jpg"):
                try:
                    facial_landmarks.get_facial_landamrks(image)
                except:
                    print("skipped")
# Out:
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# ...

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_train_val_test\fer_train_val_test\test\Unknown"
os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_train_val_test\fer_train_val_test\test\Unknown")
for image in os.listdir(directory):
    if image.endswith(".jpg"):
        try:
            facial_landmarks.get_facial_landmarks(image)
        except:
            print("skipped")
