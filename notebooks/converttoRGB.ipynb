# %%
import os
from graytorgb import convertgraytoRGB

# %% [markdown]
# # fer_train_val_test folder

# %% [markdown]
# ## Convert all images in the fer_mediapipe folder
# ### Train

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\train" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\train\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\train\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Val

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\val" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\val\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\val\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\test\Unknown"
os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\fer_mediapipe\fer_train_val_test\test\Unknown")
for image in os.listdir(directory):
    if image.endswith(".jpg"):
        try:
            convertgraytoRGB.ConvertGraytoRGB(image)
        except:
            print("skipped")

# %% [markdown]
# # ckplus_train_val_test folder

# %% [markdown]
# ## Convert all images in the ckplus_train_val_test folder
# ### Train

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\train" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\train\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\train\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Val

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\val" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\val\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\val\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\test\Unknown"
os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\ckplus_train_val_test\ckplus_train_val_test\test\Unknown")
for image in os.listdir(directory):
    if image.endswith(".jpg"):
        try:
            convertgraytoRGB.ConvertGraytoRGB(image)
        except:
            print("skipped")

# %% [markdown]
# # KDEF folder

# %% [markdown]
# ## Convert all images in the KDEF folder
# ### Train

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\train" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\train\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\train\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Val

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\val" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\val\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\val\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\test\Unknown"
os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\kdef_train_val_test\kdef_train_val_test\test\Unknown")
for image in os.listdir(directory):
    if image.endswith(".jpg"):
        try:
            convertgraytoRGB.ConvertGraytoRGB(image)
        except:
            print("skipped")

# %% [markdown]
# # AffectNet folder

# %% [markdown]
# ## Convert all images in the AffectNet folder
# ### Train

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train" # [train, val, test] folders
# ----> 2 for classes in os.listdir(directory):
#       3     class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train\\" + classes # emotions
#       4     os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\train\\" + classes)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\kings\\OneDrive - MMU\\MSC DATA SCIENCE\\MSC Project\\datasets\\affectnet_train_val_test\\affectnet_train_val_test\\train'

# %% [markdown]
# ### Val

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\val" # [train, val, test] folders
for classes in os.listdir(directory):
    class_directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\val\\" + classes # emotions
    os.chdir(r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\val\\" + classes)
    for image in os.listdir(class_directory):
        if image.endswith(".jpg"):
            try:
                convertgraytoRGB.ConvertGraytoRGB(image)
            except:
                print("skipped")

# %% [markdown]
# ### Test

# %%
directory = r"C:\Users\kings\OneDrive - MMU\MSC DATA SCIENCE\MSC Project\datasets\affectnet_train_val_test\affectnet_train_val_test\test\Unknown"
for image in os.listdir(directory):
    if image.endswith(".jpg"):
        try:
            convertgraytoRGB.ConvertGraytoRGB(image)
        except:
            print("skipped")
# Out:
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# ...
